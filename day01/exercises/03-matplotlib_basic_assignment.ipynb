# %% [markdown]
# # Matplotlib exercices

# %% [markdown]
# In this exercise, we are using Pandas and Matplotlib to visualize Company Sales Data. The data is located under the folder `../data/company_sales_data.csv`.
#
# ![company_sales_data](../data/company_sales_data.webp)

# %% [markdown]
# ## Exercise 1
# **Read Total profit of all months and show it using a line plot**
#
# Total profit data provided for each month. Generated line plot must include the following properties:
# - X label name = Month Number
# - Y label name = Total profit
# The line plot graph should look like this.
#
# **Expected output**
#
# <img src="../data/Company_profit_per_month.png" alt="Company_profit_per_month" style="width: 500px;"/>

# %%
#requiement and data
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
company_sales = pd.read_csv('../data/company_sales_data.csv')
company_sales
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
# Write your code here
fig = plt.gcf()
fig.set_size_inches(10, 4.5)

plt.plot(company_sales['month_number'],company_sales['total_profit'])
plt.xlabel("Month number")
plt.ylabel("profit in dollar")
plt.title("company profit per month")
plt.show()

# %% [markdown]
# ## Exercise 2
# **Get total profit of all months and show line plot with the following Style properties**
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# **Expected output**
#
# <img src="../data/company_sales_data_of_last_year.png" alt="company_sales_data_of_last_year" style="width: 700px;"/>

# %%
# write your code here
fig = plt.gcf()
fig.set_size_inches(12.5, 4.5)

plt.plot(company_sales['month_number'],company_sales['total_profit'],'r--',
         linewidth=3,marker = 'o',mec = 'black', label='profit of last year')


plt.xlabel("Month number")
plt.ylabel("Sold units number")
plt.title("company profit per month")

plt.legend(loc="lower right")


# Show the figure
plt.show()

# %% [markdown]
# ## Exercise 3
# **Read all product sales data and show it  using a multiline plot**
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
# **Expected output**
#
# <img src="../data/sales_data.png" alt="sales_data" style="width: 500px;"/>

# %%
# write your code here
fig = plt.gcf()
fig.set_size_inches(10, 5.5)

plt.plot(company_sales['month_number'],company_sales['facecream'],
         marker = 'o',mec = 'black', label='face cream sales data')

plt.plot(company_sales['month_number'],company_sales['facewash'],
        marker = 'o',mec = 'black', label='face wash sales data')

plt.plot(company_sales['month_number'],company_sales['toothpaste'],
         marker = 'o',mec = 'black', label='toothpaste sales data')

plt.plot(company_sales['month_number'],company_sales['bathingsoap'],
         marker = 'o',mec = 'black', label='bathingsoap sales data')

plt.plot(company_sales['month_number'],company_sales['shampoo'],
         marker = 'o',mec = 'black', label='shampoo sales data')

plt.plot(company_sales['month_number'],company_sales['moisturizer'],
         marker = 'o',mec = 'black', label='moisturizer sales data')

plt.xlabel("Month number")
plt.ylabel("Sold units in number")
plt.title("company profit per month")

plt.legend(loc="upper left")

plt.show()

# %% [markdown]
# ## Exercise 4
# **Read toothpaste sales data of each month and show it using a scatter plot**
# Also, add a grid in the plot. gridline style should “–“.
#
# **Expected output**
#
# <img src="../data/Tooth_paste_Sales_data.png" alt="sales_data" style="width: 700px;"/>

# %%
# write your code here
fig = plt.gcf()
fig.set_size_inches(10, 4.5)
plt.scatter(company_sales['month_number'],company_sales['toothpaste'],label='profit of last year')
plt.grid(True,linewidth=0.5,color='#aaaaaa',linestyle='--')
plt.xlabel("Month number")
plt.ylabel("Sold units in number")
plt.title("tooth paste sales data")
# Out:
# Text(0.5, 1.0, 'tooth paste sales data')

# %% [markdown]
# ## Exercise 5
# **Read face cream and facewash product sales data and show it using the bar chart**
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# **Expected output**
#
# <img src="../data/Facewash_and_facecream_sales_data.png" alt="sales_data" style="width: 700px;"/>

# %%
# write your code here
fig = plt.gcf()
fig.set_size_inches(10, 4.5)


barWidth = 0.25
 
# set heights of bars
bars2 = company_sales['facewash']
bars1 = company_sales['facecream']
 
# Set position of bar on X axis
r1 = company_sales['month_number']
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, width=barWidth, edgecolor='white', label='face cream sales data')
plt.bar(r2, bars2, width=barWidth, edgecolor='white', label='face wash sales data')
plt.grid(True,linewidth=0.5,color='#aaaaaa',linestyle='--')

plt.xlabel("Month number")
plt.ylabel("Sold units in number")
plt.title("facecream and facewash sales data")

plt.show()

# %% [markdown]
# ## Exercise 6
# **Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk**
#
# **Expected output**
#
# <img src="../data/sales_data_of_bathingsoap.png" alt="sales_data_of_bathingsoap" style="width: 700px;"/>

# %%
# write your code here
fig = plt.gcf()
fig.set_size_inches(10, 4.5)
plt.bar(company_sales['month_number'],company_sales['bathingsoap'])

plt.xlabel("Month number")
plt.ylabel("Sold units in number")
plt.title("bathingsoap sales data")

plt.show()

plt.savefig('bathingsaoap_sales_data.png')

# %% [markdown]
# ## Exercise 7
# **Read the total profit of each month and show it using the histogram to see the most common profit ranges**
#
# **Expected output**
#
# <img src="../data/Profit_data.png" alt="Profit_data" style="width: 700px;"/>

# %%
# write your code here
fig = plt.gcf()
fig.set_size_inches(10, 4.5)

plt.xlim(150000,380000)
plt.ylim(0,7)
plt.hist(company_sales['total_profit'],bins = [175000, 200000, 225000, 250000, 300000, 350000], label = 'Profit data')

plt.xlabel("Month number")
plt.ylabel("Sold units in number")
plt.title("bathingsoap sales data")
plt.legend(loc="upper left")

plt.show()

# %% [markdown]
# ## Exercise 8
# **Calculate total sale data for last year for each product and show it using a Pie chart**
#
# *Note: In Pie chart display Number of units sold per year for each product in percentage.*
#
# **Expected output**
#
# <img src="../data/sales_data_pi_chart.png" alt="sales_data_pi_chart" style="width: 700px;"/>

# %%
# write your code here
total_sales_per_product = company_sales.sum(axis = 0)

labels = list(company_sales.columns)[1:6]

fig, ax = plt.subplots(figsize =(10, 7))
ax.pie(total_sales_per_product[1:6],labels = list(company_sales.columns)[1:6], autopct='%1.1f%%')
plt.legend(loc="lower right")

# show plot
plt.show()

# %% [markdown]
# ## Exercise 9
# **Read Bathing soap facewash of all months and display it using the Subplot**
#
# **Expected output**
#
# <img src="../data/Sales_data_of_a_facewash.png" alt="Sales_data_of_a_facewash" style="width: 700px;"/>

# %%
# write your code here
fig = plt.gcf()
fig.set_size_inches(10, 4.5)
plt.subplot(2, 1, 1)
plt.plot(company_sales['month_number'], company_sales['bathingsoap'],linewidth=3)
plt.ylabel("Sold units in number")
plt.title("sales data of bathingsoap")

plt.subplot(2, 1, 2)
plt.plot(company_sales['month_number'], company_sales['bathingsoap'], color = 'red', linewidth=3)
plt.ylabel("Sold units in number")
plt.title("sales data of facewash")



plt.show()

# %% [markdown]
# ## Exercise 10
# **Read all product sales data and show it using the stack plot**
#
# **Expected output**
#
# <img src="../data/product_sales_stack_plot.png" alt="product_sales_stack_plot" style="width: 700px;"/>

# %%
# write your code here
company_sales
fig = plt.gcf()
fig.set_size_inches(10, 4.5)

plt.stackplot(company_sales["month_number"],company_sales["facecream"], company_sales["facewash"], company_sales['toothpaste'],
            company_sales['bathingsoap'],company_sales['shampoo'],company_sales['moisturizer'])
plt.show()
